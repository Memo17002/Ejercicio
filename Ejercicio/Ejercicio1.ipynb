# %% [markdown]
# # Ejercicio 1

# %% [markdown]
# Una compañía fabrica dos tipos de motores pequeños con combustible sólido. Con el motor A gana $3\$$ por motor y con el motor B gana $4\$$ por motor. Dispone de 80 horas por semana para producirlos y en los procesos se requieren: 4 h para A y solo 2 h para B. Sin embargo, debido a lo peligroso del material usado, son necesarias 5 h de preparación y limpieza para el motor B y 2 h para A. El tiempo de preparación total disponible es 120 h por semana. Determinar el número de cada clase de motores a producir que dé como resultado la máxima ganancia.

# %% [markdown]
# ### Variables de decisión:

# %% [markdown]
# Motor $A, x_{1}$ y $B,x_{2}$

# %% [markdown]
# ### Función objetivo

# %% [markdown]
# Maximizar $3x_{1}+4x_{2}$

# %% [markdown]
# ### Restricciones

# %% [markdown]
# $M_{1}$: $4x_{1}+2x_{2}\leq 80$

# %% [markdown]
# $M_{2}$: $2x_{1}+5x_{2}\leq 120$

# %% [markdown]
# No negatividad: $x_{1} \geq 0$, $x_{2} \geq 0$

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure()
    
# Restricción para M1
plt.plot([0, 80.0/4.0], [80.0/2.0, 0], color='orange', alpha=0.25)
plt.fill_between([0, 80.0/4.0], [80.0/2.0, 0], color='orange', alpha=0.25, label='resultante de M1')

plt.xlabel('recipientes K')
plt.ylabel('recipientes L')
plt.legend()
plt.show()

# %%
# Restricción para M1
plt.plot([0, 80.0/4.0], [80.0/2.0, 0], color='orange', alpha=0.25)
plt.fill_between([0, 80.0/4.0], [80.0/2.0, 0], color='orange', alpha=0.25, label='resultante de M1')
# Restricción para M2
plt.plot([0, 120.0/2.0], [120.0/5.0, 0], color='blue', alpha=0.125)
plt.fill_between([0, 120.0/2.0], [120.0/5.0, 0], color='blue', alpha=0.125, label='resultante de M2')

plt.xlabel('recipientes K')
plt.ylabel('recipientes L')
plt.legend()
plt.show()

# %%
# Restricción para M1
plt.plot([0, 80.0/4.0], [80.0/2.0, 0], color='orange', alpha=0.25)
plt.fill_between([0, 80.0/4.0], [80.0/2.0, 0], color='orange', alpha=0.25, label='resultante de M1')
# Restricción para M2
plt.plot([0, 120.0/2.0], [120.0/5.0, 0], color='blue', alpha=0.125)
plt.fill_between([0, 120.0/2.0], [120.0/5.0, 0], color='blue', alpha=0.125, label='resultante de M2')

plt.xlabel('recipientes K')
plt.ylabel('recipientes L')

plt.scatter([8], [9])  # punto factible

plt.xlim(0)
plt.ylim(0)

plt.legend()
plt.show()

# %% [markdown]
# $z_{1}=3*8+4*9=60$

# %%
# Restricción para M1
plt.plot([0, 80.0/4.0], [80.0/2.0, 0], color='orange', alpha=0.25)
plt.fill_between([0, 80.0/4.0], [80.0/2.0, 0], color='orange', alpha=0.25, label='resultante de M1')
# Restricción para M2
plt.plot([0, 120.0/2.0], [120.0/5.0, 0], color='blue', alpha=0.125)
plt.fill_between([0, 120.0/2.0], [120.0/5.0, 0], color='blue', alpha=0.125, label='resultante de M2')

plt.xlabel('recipientes K')
plt.ylabel('recipientes L')

plt.scatter([8], [9])  # punto factible
plt.plot([0, 60.0/3], [60.0/4, 0], color='black')
plt.xlim(0)
plt.ylim(0)

plt.legend()
plt.show()

# %%
# Restricción para M1
plt.plot([0, 80.0/4.0], [80.0/2.0, 0], color='orange', alpha=0.25)
plt.fill_between([0, 80.0/4.0], [80.0/2.0, 0], color='orange', alpha=0.25, label='resultante de M1')
# Restricción para M2
plt.plot([0, 120.0/2.0], [120.0/5.0, 0], color='blue', alpha=0.125)
plt.fill_between([0, 120.0/2.0], [120.0/5.0, 0], color='blue', alpha=0.125, label='resultante de M2')

plt.xlabel('recipientes K')
plt.ylabel('recipientes L')

plt.scatter([8], [9])  # punto factible
plt.plot([0, 60.0/3], [60.0/4, 0], color='black')

plt.scatter([10], [20], color='red')  # punto factible
plt.plot([0, 110.0/3], [110.0/4, 0], color='red', linestyle='-.')

plt.xlim(0)
plt.ylim(0)

plt.legend()
plt.show()
